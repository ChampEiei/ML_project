# %%
import pandas as pd
df = pd.read_csv('../artifacts/train.csv')
df
# Out:
#        source_city departure_time stops arrival_time destination_city  \
# 0            Delhi          Night   one      Morning           Mumbai
# 1        Hyderabad        Morning   one      Evening            Delhi
# 2          Chennai  Early_Morning   one      Evening          Kolkata
# 3            Delhi        Evening   one        Night        Bangalore
# 4        Bangalore        Morning   one        Night            Delhi
# ...            ...            ...   ...          ...              ...
# 210102     Kolkata        Evening   one    Afternoon            Delhi
# 210103   Bangalore          Night   one        Night          Chennai
# 210104     Kolkata          Night   one      Morning           Mumbai
# 210105     Kolkata      Afternoon   one        Night        Hyderabad
# 210106     Kolkata      Afternoon   one      Morning            Delhi
#
#            class  duration  days_left  price
# 0        Economy     13.42         14   8483
# ...

# %%
lst=['duration' , 'days_left' ,'source_city'  ,'departure_time' ,'stops'  ,'arrival_time'  ,'destination_city'  , 'class']

# %%
df = df[lst]

# %%
for i,v in enumerate(df.columns):
    print(v)
    print(df[v].unique())
    print('\n')
# Out:
# duration
# [13.42  9.58 11.17  5.08 12.58 16.92 12.92 14.83 12.   20.75 15.25  6.08
#  10.   22.33  9.42  2.17 14.    5.58  4.67  7.42  6.    2.42  6.33  6.17
#   8.08 19.5  11.33 19.33  1.5  26.5  20.17  6.67  8.75  6.75 10.67 10.92
#  12.67 16.25  1.08  9.08  5.25 27.17 15.08  5.42  4.58 11.92  5.5   5.
#  26.33 14.25 22.25  7.17 15.67 21.58 14.5   6.5   7.   15.92 11.   13.58
#   2.75 25.08 24.17 25.17 10.33 26.25 19.75  8.92  6.83 14.58  4.75  8.58
#  23.17 16.5  24.33 19.58 25.83 12.5  13.75  4.17 11.58  9.5  20.5   4.83
#  16.75  1.92 16.42 27.92  7.58  8.42  6.92  3.83 17.75  5.67 23.83 12.17
#  14.67  7.92  2.83 14.75 17.92 10.58 15.5   8.   12.33 33.83 21.08 12.83
#   9.   22.08  6.42 12.25 34.58 22.92 13.08  9.92 18.25  6.58  1.25 11.08
#  19.92 17.33 11.5  10.5  10.83  2.25  7.08 21.83 18.58  7.5  12.08  2.
#  13.    7.67  5.33 22.   13.33 20.92 14.17  8.83 20.58 25.58  8.67  2.33
#   1.58 23.25 21.25  8.25 15.33 11.42 23.5   9.17  7.33 16.08 17.   10.08
# ...

# %%
df['duration'].describe()
# Out:
# count    210107.000000
# mean         12.211991
# std           7.188388
# min           0.830000
# 25%           6.750000
# 50%          11.250000
# 75%          16.170000
# max          49.830000
# Name: duration, dtype: float64
